# %%
import nltk
import numpy as np
import time
from sklearn.metrics import confusion_matrix, f1_score, accuracy_score, precision_score, recall_score
from sklearn.model_selection import StratifiedKFold, KFold
from utils import create_embedding_matrix
from utils import Attention
from utils import DataLoader
import pandas as pd
import zipfile
from utils import sensitivity, specificity, run_model_on_fold
from nn_models import build_model1, build_model3, build_model4, build_model5
pd.set_option('max_colwidth', 400)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
X, y = DataLoader('./data/Ethos_Dataset_Binary.csv').get_data()
class_names = ['noHateSpeech', 'hateSpeech']
f = open("setC.txt", "a+")
f.write("{:<10} | {:<7} {:<7} {:<7} {:<7} {:<7} {:<7} \n".format(
    'Method', 'F1score', 'Precisi', 'Recall', 'Accurac', 'Specifi', 'Sensiti'))
f.write("=========================================================================\n")
f.close()
print("{:<10} | {:<7} {:<7} {:<7} {:<7} {:<7} {:<7}".format(
    'Method', 'F1score', 'Precisi', 'Recall', 'Accurac', 'Specifi', 'Sensiti'))
# Out:
# Loaded file : Ethos_Dataset_Binary.csv
# Method     | F1score Precisi Recall  Accurac Specifi Sensiti

# %%
# !wget 'https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip'
# !unzip crawl-300d-2M.vec.zip
# !mkdir embeddings
# !mv crawl-300d-2M.vec embeddings/crawl-300d-2M.vec
# !rm crawl-300d-2M.vec.zip
# Out:
# --2021-03-16 03:11:09--  https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1523785255 (1.4G) [application/zip]
# Saving to: ‘crawl-300d-2M.vec.zip’
#
# crawl-300d-2M.vec.z 100%[===================>]   1.42G  9.48MB/s    in 76s
#
# 2021-03-16 03:12:26 (19.0 MB/s) - ‘crawl-300d-2M.vec.zip’ saved [1523785255/1523785255]

# %%
embed_size = 300

n_fold = 10
folds = StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=7)

# %%
for emb_ma in [1, 2, 3]:
    print('*', end='')
    embed_size = 150  # * 2 = 300 for matrix 1 and 2
    if emb_ma == 3:
        embed_size = 300
    for max_len in [100, 150, 200, 250, 300]:
        print(".", end='')
        run_model_on_fold('b1_'+str(emb_ma)+'_'+str(max_len),
                          max_len, embed_size, emb_ma, build_model1, folds, X,y)
# Out:
# *.Fold 0 started at Tue Mar 16 03:25:06 2021
# Please download and put this embeddings to the folder ethos/experiments/embeddings:
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# Epoch 1/20
# 57/57 [==============================] - 4s 62ms/step - loss: 0.6942 - accuracy: 0.5676 - val_loss: 0.6487 - val_accuracy: 0.7300
#
# Epoch 00001: val_accuracy improved from -inf to 0.73000, saving model to best_model_fold_0.hdf5
# Epoch 2/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.6019 - accuracy: 0.7068 - val_loss: 0.5334 - val_accuracy: 0.7400
#
# Epoch 00002: val_accuracy improved from 0.73000 to 0.74000, saving model to best_model_fold_0.hdf5
# Epoch 3/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.4187 - accuracy: 0.8308 - val_loss: 0.5251 - val_accuracy: 0.7500
#
# Epoch 00003: val_accuracy improved from 0.74000 to 0.75000, saving model to best_model_fold_0.hdf5
# Epoch 4/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.2630 - accuracy: 0.8806 - val_loss: 0.6113 - val_accuracy: 0.7800
#
# Epoch 00004: val_accuracy improved from 0.75000 to 0.78000, saving model to best_model_fold_0.hdf5
# Epoch 5/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1340 - accuracy: 0.9614 - val_loss: 0.5906 - val_accuracy: 0.7800
#
# Epoch 00005: val_accuracy did not improve from 0.78000
# Epoch 6/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0904 - accuracy: 0.9727 - val_loss: 0.7398 - val_accuracy: 0.7900
#
# Epoch 00006: val_accuracy improved from 0.78000 to 0.79000, saving model to best_model_fold_0.hdf5
# Epoch 7/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0370 - accuracy: 0.9910 - val_loss: 0.8442 - val_accuracy: 0.7700
#
# Epoch 00007: val_accuracy did not improve from 0.79000
# Epoch 8/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0258 - accuracy: 0.9954 - val_loss: 0.9408 - val_accuracy: 0.7100
#
# Epoch 00008: val_accuracy did not improve from 0.79000
# Epoch 9/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0293 - accuracy: 0.9878 - val_loss: 0.9004 - val_accuracy: 0.7700
#
# Epoch 00009: val_accuracy did not improve from 0.79000
# Epoch 10/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0135 - accuracy: 0.9973 - val_loss: 0.9333 - val_accuracy: 0.7700
#
# Epoch 00010: val_accuracy did not improve from 0.79000
# 0.79
# Fold 1 started at Tue Mar 16 03:27:28 2021
# Please download and put this embeddings to the folder ethos/experiments/embeddings:
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# Epoch 1/20
# 57/57 [==============================] - 2s 24ms/step - loss: 0.6973 - accuracy: 0.5379 - val_loss: 0.6531 - val_accuracy: 0.6500
#
# Epoch 00001: val_accuracy improved from -inf to 0.65000, saving model to best_model_fold_1.hdf5
# Epoch 2/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.5899 - accuracy: 0.7062 - val_loss: 0.6046 - val_accuracy: 0.6700
#
# Epoch 00002: val_accuracy improved from 0.65000 to 0.67000, saving model to best_model_fold_1.hdf5
# Epoch 3/20
# 57/57 [==============================] - 1s 26ms/step - loss: 0.4010 - accuracy: 0.8252 - val_loss: 0.6709 - val_accuracy: 0.7000
#
# Epoch 00003: val_accuracy improved from 0.67000 to 0.70000, saving model to best_model_fold_1.hdf5
# Epoch 4/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.2385 - accuracy: 0.9354 - val_loss: 0.8464 - val_accuracy: 0.6400
#
# Epoch 00004: val_accuracy did not improve from 0.70000
# Epoch 5/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1842 - accuracy: 0.9165 - val_loss: 0.9761 - val_accuracy: 0.6200
#
# Epoch 00005: val_accuracy did not improve from 0.70000
# Epoch 6/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0653 - accuracy: 0.9844 - val_loss: 1.2051 - val_accuracy: 0.6400
#
# Epoch 00006: val_accuracy did not improve from 0.70000
# Epoch 7/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0228 - accuracy: 0.9976 - val_loss: 1.3689 - val_accuracy: 0.6400
#
# Epoch 00007: val_accuracy did not improve from 0.70000
# 0.7
# Fold 2 started at Tue Mar 16 03:30:13 2021
# Please download and put this embeddings to the folder ethos/experiments/embeddings:
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# Epoch 1/20
# 57/57 [==============================] - 2s 23ms/step - loss: 0.7099 - accuracy: 0.5012 - val_loss: 0.6715 - val_accuracy: 0.6000
#
# Epoch 00001: val_accuracy improved from -inf to 0.60000, saving model to best_model_fold_2.hdf5
# Epoch 2/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.6531 - accuracy: 0.6458 - val_loss: 0.5090 - val_accuracy: 0.7900
#
# Epoch 00002: val_accuracy improved from 0.60000 to 0.79000, saving model to best_model_fold_2.hdf5
# Epoch 3/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.4998 - accuracy: 0.7612 - val_loss: 0.4925 - val_accuracy: 0.7500
#
# Epoch 00003: val_accuracy did not improve from 0.79000
# Epoch 4/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.3140 - accuracy: 0.8792 - val_loss: 0.6001 - val_accuracy: 0.6400
#
# Epoch 00004: val_accuracy did not improve from 0.79000
# Epoch 5/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.2241 - accuracy: 0.9229 - val_loss: 0.6022 - val_accuracy: 0.7700
#
# Epoch 00005: val_accuracy did not improve from 0.79000
# Epoch 6/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1166 - accuracy: 0.9698 - val_loss: 0.6285 - val_accuracy: 0.7300
#
# Epoch 00006: val_accuracy did not improve from 0.79000
# 0.79
# Fold 3 started at Tue Mar 16 03:32:26 2021
# Please download and put this embeddings to the folder ethos/experiments/embeddings:
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# Epoch 1/20
# 57/57 [==============================] - 2s 23ms/step - loss: 0.7052 - accuracy: 0.5027 - val_loss: 0.6833 - val_accuracy: 0.5700
#
# Epoch 00001: val_accuracy improved from -inf to 0.57000, saving model to best_model_fold_3.hdf5
# Epoch 2/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.6227 - accuracy: 0.6596 - val_loss: 0.5889 - val_accuracy: 0.7300
#
# Epoch 00002: val_accuracy improved from 0.57000 to 0.73000, saving model to best_model_fold_3.hdf5
# Epoch 3/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.4462 - accuracy: 0.8068 - val_loss: 0.5864 - val_accuracy: 0.7500
#
# Epoch 00003: val_accuracy improved from 0.73000 to 0.75000, saving model to best_model_fold_3.hdf5
# Epoch 4/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.2520 - accuracy: 0.9091 - val_loss: 0.6112 - val_accuracy: 0.7900
#
# Epoch 00004: val_accuracy improved from 0.75000 to 0.79000, saving model to best_model_fold_3.hdf5
# Epoch 5/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1094 - accuracy: 0.9761 - val_loss: 0.6445 - val_accuracy: 0.7800
#
# Epoch 00005: val_accuracy did not improve from 0.79000
# Epoch 6/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0486 - accuracy: 0.9903 - val_loss: 0.9555 - val_accuracy: 0.7600
#
# Epoch 00006: val_accuracy did not improve from 0.79000
# Epoch 7/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0646 - accuracy: 0.9699 - val_loss: 0.8882 - val_accuracy: 0.7300
#
# Epoch 00007: val_accuracy did not improve from 0.79000
# Epoch 8/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0219 - accuracy: 0.9938 - val_loss: 0.8523 - val_accuracy: 0.7900
#
# Epoch 00008: val_accuracy did not improve from 0.79000
# 0.79
# Fold 4 started at Tue Mar 16 03:34:42 2021
# Please download and put this embeddings to the folder ethos/experiments/embeddings:
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# Epoch 1/20
# 57/57 [==============================] - 2s 22ms/step - loss: 0.6923 - accuracy: 0.5345 - val_loss: 0.6657 - val_accuracy: 0.6600
#
# Epoch 00001: val_accuracy improved from -inf to 0.66000, saving model to best_model_fold_4.hdf5
# Epoch 2/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.6399 - accuracy: 0.6351 - val_loss: 0.6082 - val_accuracy: 0.6500
#
# Epoch 00002: val_accuracy did not improve from 0.66000
# Epoch 3/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.5069 - accuracy: 0.7438 - val_loss: 0.4949 - val_accuracy: 0.7500
#
# Epoch 00003: val_accuracy improved from 0.66000 to 0.75000, saving model to best_model_fold_4.hdf5
# Epoch 4/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.3123 - accuracy: 0.8903 - val_loss: 0.5276 - val_accuracy: 0.7400
#
# Epoch 00004: val_accuracy did not improve from 0.75000
# Epoch 5/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1145 - accuracy: 0.9701 - val_loss: 0.8617 - val_accuracy: 0.7100
#
# Epoch 00005: val_accuracy did not improve from 0.75000
# Epoch 6/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1057 - accuracy: 0.9612 - val_loss: 0.7828 - val_accuracy: 0.7000
#
# Epoch 00006: val_accuracy did not improve from 0.75000
# Epoch 7/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0404 - accuracy: 0.9918 - val_loss: 1.1052 - val_accuracy: 0.7000
#
# Epoch 00007: val_accuracy did not improve from 0.75000
# 0.75
# Fold 5 started at Tue Mar 16 03:36:55 2021
# Please download and put this embeddings to the folder ethos/experiments/embeddings:
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# Epoch 1/20
# 57/57 [==============================] - 2s 22ms/step - loss: 0.7115 - accuracy: 0.5057 - val_loss: 0.6719 - val_accuracy: 0.6200
#
# Epoch 00001: val_accuracy improved from -inf to 0.62000, saving model to best_model_fold_5.hdf5
# Epoch 2/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.6471 - accuracy: 0.6549 - val_loss: 0.5902 - val_accuracy: 0.7000
#
# Epoch 00002: val_accuracy improved from 0.62000 to 0.70000, saving model to best_model_fold_5.hdf5
# Epoch 3/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.5147 - accuracy: 0.7471 - val_loss: 0.5380 - val_accuracy: 0.7500
#
# Epoch 00003: val_accuracy improved from 0.70000 to 0.75000, saving model to best_model_fold_5.hdf5
# Epoch 4/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.3951 - accuracy: 0.8350 - val_loss: 0.5223 - val_accuracy: 0.7200
#
# Epoch 00004: val_accuracy did not improve from 0.75000
# Epoch 5/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1758 - accuracy: 0.9430 - val_loss: 0.6142 - val_accuracy: 0.8000
#
# Epoch 00005: val_accuracy improved from 0.75000 to 0.80000, saving model to best_model_fold_5.hdf5
# Epoch 6/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0878 - accuracy: 0.9761 - val_loss: 0.6611 - val_accuracy: 0.7400
#
# Epoch 00006: val_accuracy did not improve from 0.80000
# Epoch 7/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0527 - accuracy: 0.9910 - val_loss: 0.7588 - val_accuracy: 0.7100
#
# Epoch 00007: val_accuracy did not improve from 0.80000
# Epoch 8/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0306 - accuracy: 0.9902 - val_loss: 1.1518 - val_accuracy: 0.6700
#
# Epoch 00008: val_accuracy did not improve from 0.80000
# Epoch 9/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0218 - accuracy: 0.9929 - val_loss: 1.1198 - val_accuracy: 0.6600
#
# Epoch 00009: val_accuracy did not improve from 0.80000
# 0.8
# Fold 6 started at Tue Mar 16 03:39:15 2021
# Please download and put this embeddings to the folder ethos/experiments/embeddings:
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# Epoch 1/20
# 57/57 [==============================] - 2s 24ms/step - loss: 0.6921 - accuracy: 0.5655 - val_loss: 0.6642 - val_accuracy: 0.6600
#
# Epoch 00001: val_accuracy improved from -inf to 0.66000, saving model to best_model_fold_6.hdf5
# Epoch 2/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.5908 - accuracy: 0.6969 - val_loss: 0.5872 - val_accuracy: 0.7300
#
# Epoch 00002: val_accuracy improved from 0.66000 to 0.73000, saving model to best_model_fold_6.hdf5
# Epoch 3/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.3935 - accuracy: 0.8295 - val_loss: 0.6163 - val_accuracy: 0.7200
#
# Epoch 00003: val_accuracy did not improve from 0.73000
# Epoch 4/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.3066 - accuracy: 0.8818 - val_loss: 0.6109 - val_accuracy: 0.7500
#
# Epoch 00004: val_accuracy improved from 0.73000 to 0.75000, saving model to best_model_fold_6.hdf5
# Epoch 5/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.2188 - accuracy: 0.9109 - val_loss: 0.6680 - val_accuracy: 0.7600
#
# Epoch 00005: val_accuracy improved from 0.75000 to 0.76000, saving model to best_model_fold_6.hdf5
# Epoch 6/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1018 - accuracy: 0.9680 - val_loss: 0.7306 - val_accuracy: 0.7200
#
# Epoch 00006: val_accuracy did not improve from 0.76000
# Epoch 7/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0354 - accuracy: 0.9951 - val_loss: 0.8534 - val_accuracy: 0.7300
#
# Epoch 00007: val_accuracy did not improve from 0.76000
# Epoch 8/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0403 - accuracy: 0.9899 - val_loss: 0.9304 - val_accuracy: 0.7400
#
# Epoch 00008: val_accuracy did not improve from 0.76000
# Epoch 9/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0565 - accuracy: 0.9781 - val_loss: 0.8783 - val_accuracy: 0.7500
#
# Epoch 00009: val_accuracy did not improve from 0.76000
# 0.76
# Fold 7 started at Tue Mar 16 03:41:37 2021
# Please download and put this embeddings to the folder ethos/experiments/embeddings:
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# Epoch 1/20
# 57/57 [==============================] - 2s 24ms/step - loss: 0.6871 - accuracy: 0.5606 - val_loss: 0.6676 - val_accuracy: 0.6600
#
# Epoch 00001: val_accuracy improved from -inf to 0.66000, saving model to best_model_fold_7.hdf5
# Epoch 2/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.6284 - accuracy: 0.6764 - val_loss: 0.6383 - val_accuracy: 0.6400
#
# Epoch 00002: val_accuracy did not improve from 0.66000
# Epoch 3/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.5504 - accuracy: 0.7137 - val_loss: 0.6184 - val_accuracy: 0.7000
#
# Epoch 00003: val_accuracy improved from 0.66000 to 0.70000, saving model to best_model_fold_7.hdf5
# Epoch 4/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.3433 - accuracy: 0.8639 - val_loss: 0.6334 - val_accuracy: 0.7300
#
# Epoch 00004: val_accuracy improved from 0.70000 to 0.73000, saving model to best_model_fold_7.hdf5
# Epoch 5/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.1859 - accuracy: 0.9579 - val_loss: 0.7618 - val_accuracy: 0.6800
#
# Epoch 00005: val_accuracy did not improve from 0.73000
# Epoch 6/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0946 - accuracy: 0.9674 - val_loss: 0.8300 - val_accuracy: 0.7000
#
# Epoch 00006: val_accuracy did not improve from 0.73000
# Epoch 7/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0623 - accuracy: 0.9762 - val_loss: 0.9886 - val_accuracy: 0.7200
#
# Epoch 00007: val_accuracy did not improve from 0.73000
# Epoch 8/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.0611 - accuracy: 0.9806 - val_loss: 1.0615 - val_accuracy: 0.6700
#
# Epoch 00008: val_accuracy did not improve from 0.73000
# 0.73
# Fold 8 started at Tue Mar 16 03:43:52 2021
# Please download and put this embeddings to the folder ethos/experiments/embeddings:
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# Epoch 1/20
# 57/57 [==============================] - 2s 23ms/step - loss: 0.6832 - accuracy: 0.5763 - val_loss: 0.6777 - val_accuracy: 0.5354
#
# Epoch 00001: val_accuracy improved from -inf to 0.53535, saving model to best_model_fold_8.hdf5
# Epoch 2/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.6505 - accuracy: 0.6037 - val_loss: 0.5359 - val_accuracy: 0.7273
#
# Epoch 00002: val_accuracy improved from 0.53535 to 0.72727, saving model to best_model_fold_8.hdf5
# Epoch 3/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.4935 - accuracy: 0.7880 - val_loss: 0.4833 - val_accuracy: 0.8081
#
# Epoch 00003: val_accuracy improved from 0.72727 to 0.80808, saving model to best_model_fold_8.hdf5
# Epoch 4/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.3255 - accuracy: 0.8769 - val_loss: 0.4729 - val_accuracy: 0.7677
#
# Epoch 00004: val_accuracy did not improve from 0.80808
# Epoch 5/20
# 57/57 [==============================] - 1s 21ms/step - loss: 0.1403 - accuracy: 0.9704 - val_loss: 0.5308 - val_accuracy: 0.7980
#
# Epoch 00005: val_accuracy did not improve from 0.80808
# Epoch 6/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0716 - accuracy: 0.9837 - val_loss: 0.6584 - val_accuracy: 0.7879
#
# Epoch 00006: val_accuracy did not improve from 0.80808
# Epoch 7/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0534 - accuracy: 0.9804 - val_loss: 0.8613 - val_accuracy: 0.7475
#
# Epoch 00007: val_accuracy did not improve from 0.80808
# 0.8080808080808081
# Fold 9 started at Tue Mar 16 03:46:07 2021
# Please download and put this embeddings to the folder ethos/experiments/embeddings:
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# Epoch 1/20
# 57/57 [==============================] - 2s 23ms/step - loss: 0.7049 - accuracy: 0.5553 - val_loss: 0.6819 - val_accuracy: 0.5657
#
# Epoch 00001: val_accuracy improved from -inf to 0.56566, saving model to best_model_fold_9.hdf5
# Epoch 2/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.6720 - accuracy: 0.6118 - val_loss: 0.6647 - val_accuracy: 0.6061
#
# Epoch 00002: val_accuracy improved from 0.56566 to 0.60606, saving model to best_model_fold_9.hdf5
# Epoch 3/20
# 57/57 [==============================] - 1s 19ms/step - loss: 0.5135 - accuracy: 0.7545 - val_loss: 0.6256 - val_accuracy: 0.6566
#
# Epoch 00003: val_accuracy improved from 0.60606 to 0.65657, saving model to best_model_fold_9.hdf5
# Epoch 4/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.3704 - accuracy: 0.8667 - val_loss: 0.7417 - val_accuracy: 0.6364
#
# Epoch 00004: val_accuracy did not improve from 0.65657
# Epoch 5/20
# 57/57 [==============================] - 1s 21ms/step - loss: 0.1844 - accuracy: 0.9610 - val_loss: 0.9080 - val_accuracy: 0.6364
#
# Epoch 00005: val_accuracy did not improve from 0.65657
# Epoch 6/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.1220 - accuracy: 0.9609 - val_loss: 0.9579 - val_accuracy: 0.6162
#
# Epoch 00006: val_accuracy did not improve from 0.65657
# Epoch 7/20
# 57/57 [==============================] - 1s 20ms/step - loss: 0.0412 - accuracy: 0.9938 - val_loss: 1.2929 - val_accuracy: 0.6364
#
# Epoch 00007: val_accuracy did not improve from 0.65657
# 0.6565656565656566
# b1_1_10    | 0.7540  0.7610  0.7585  0.7575  0.7523  0.7647
# .Fold 0 started at Tue Mar 16 03:48:22 2021
# Please download and put this embeddings to the folder ethos/experiments/embeddings:
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# Epoch 1/20
# 57/57 [==============================] - 2s 31ms/step - loss: 0.6953 - accuracy: 0.5594 - val_loss: 0.6729 - val_accuracy: 0.6900
#
# Epoch 00001: val_accuracy improved from -inf to 0.69000, saving model to best_model_fold_0.hdf5
# Epoch 2/20
# 57/57 [==============================] - 2s 27ms/step - loss: 0.6445 - accuracy: 0.6316 - val_loss: 0.6281 - val_accuracy: 0.6900
#
# Epoch 00002: val_accuracy did not improve from 0.69000
# Epoch 3/20
# 57/57 [==============================] - 2s 28ms/step - loss: 0.4851 - accuracy: 0.7637 - val_loss: 0.5688 - val_accuracy: 0.7200
#
# Epoch 00003: val_accuracy improved from 0.69000 to 0.72000, saving model to best_model_fold_0.hdf5
# Epoch 4/20
# 57/57 [==============================] - 2s 29ms/step - loss: 0.3269 - accuracy: 0.8871 - val_loss: 0.5982 - val_accuracy: 0.7600
#
# Epoch 00004: val_accuracy improved from 0.72000 to 0.76000, saving model to best_model_fold_0.hdf5
# Epoch 5/20
# 57/57 [==============================] - 2s 28ms/step - loss: 0.1818 - accuracy: 0.9389 - val_loss: 0.6794 - val_accuracy: 0.7600
#
# Epoch 00005: val_accuracy did not improve from 0.76000
# Epoch 6/20
# 57/57 [==============================] - 2s 27ms/step - loss: 0.0650 - accuracy: 0.9804 - val_loss: 0.7692 - val_accuracy: 0.7400
#
# Epoch 00006: val_accuracy did not improve from 0.76000
# Epoch 7/20
# 57/57 [==============================] - 2s 28ms/step - loss: 0.0486 - accuracy: 0.9834 - val_loss: 0.7496 - val_accuracy: 0.7300
#
# Epoch 00007: val_accuracy did not improve from 0.76000
# Epoch 8/20
# 57/57 [==============================] - 2s 28ms/step - loss: 0.0282 - accuracy: 0.9965 - val_loss: 0.8353 - val_accuracy: 0.7700
#
# Epoch 00008: val_accuracy improved from 0.76000 to 0.77000, saving model to best_model_fold_0.hdf5
# Epoch 9/20
# 57/57 [==============================] - 2s 27ms/step - loss: 0.0120 - accuracy: 0.9988 - val_loss: 0.9431 - val_accuracy: 0.7600
#
# Epoch 00009: val_accuracy did not improve from 0.77000
# Epoch 10/20
# 57/57 [==============================] - 2s 27ms/step - loss: 0.0125 - accuracy: 0.9970 - val_loss: 1.0382 - val_accuracy: 0.7400
#
# Epoch 00010: val_accuracy did not improve from 0.77000
# Epoch 11/20
# 57/57 [==============================] - 2s 28ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 1.5164 - val_accuracy: 0.6900
#
# Epoch 00011: val_accuracy did not improve from 0.77000
# Epoch 12/20
# 57/57 [==============================] - 2s 28ms/step - loss: 0.0471 - accuracy: 0.9808 - val_loss: 0.8807 - val_accuracy: 0.7800
#
# Epoch 00012: val_accuracy improved from 0.77000 to 0.78000, saving model to best_model_fold_0.hdf5
# Epoch 13/20
# 57/57 [==============================] - 2s 27ms/step - loss: 0.0373 - accuracy: 0.9853 - val_loss: 1.1731 - val_accuracy: 0.7200
#
# Epoch 00013: val_accuracy did not improve from 0.78000
# Epoch 14/20
# 57/57 [==============================] - 2s 28ms/step - loss: 0.0185 - accuracy: 0.9908 - val_loss: 1.0837 - val_accuracy: 0.7300
#
# Epoch 00014: val_accuracy did not improve from 0.78000
# Epoch 15/20
# 57/57 [==============================] - 2s 27ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 1.0744 - val_accuracy: 0.7500
#
# Epoch 00015: val_accuracy did not improve from 0.78000
# Epoch 16/20
# 57/57 [==============================] - 2s 27ms/step - loss: 0.0113 - accuracy: 0.9944 - val_loss: 1.1471 - val_accuracy: 0.7300
#
# Epoch 00016: val_accuracy did not improve from 0.78000
# 0.78
# Fold 1 started at Tue Mar 16 03:50:55 2021
# Please download and put this embeddings to the folder ethos/experiments/embeddings:
# https://dl.fbaipublicfiles.com/fasttext/vectors-english/crawl-300d-2M.vec.zip
# ---------------------------------------------------------------------------
# KernelInterrupted: Execution interrupted by the Jupyter kernel.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=82b9920f-8f69-4e4d-89ee-551e9484231d' target="_blank">
# <img style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
